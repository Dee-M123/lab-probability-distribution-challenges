# %% [markdown]
# # Lab | Probability Distributions

# %% [markdown]
# Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom
import seaborn as sns

# %% [markdown]
# # Challenge 1 - Plot Probability Mass Function (PMF)

# %% [markdown]
# #### Background knowledge
#
# [PMF](https://en.wikipedia.org/wiki/Probability_mass_function) shows the probability distribution of a **discrete random variable**. A [discrete random variable](https://en.wikipedia.org/wiki/Random_variable#Discrete_random_variable) has random numeric values that are not continuous. For example, the number of people in a household can only be integers but not floats. Therefore the number of people in a household is a discrete variable.
#
# #### Question: We assume that the probability of clicking an Ad in a Youtube video is 0.15. We have a sample of 5 people who wathched the video and we want to plot the PMF for a binomial distribution.
#
# *Hint: use binom from `scipy.stats.binom`. Your output should look like below:*
#
# ![binom 10](ch-2.png)

# %%
n = 5
p = 0.15


k = np.arange(0, 6)

# PMF values
pmf = binom.pmf(k, n, p)

# Plot
plt.figure()
plt.bar(k, pmf)
plt.xlabel("Number of Clicks")
plt.ylabel("Probability")
plt.title("Binomial PMF (n = 5, p = 0.15)")
plt.xticks(k)
plt.show()

# %% [markdown]
# #### Explain what you observe from the plot above

# %%
# probability decreases as clicks increase

# %% [markdown]
# #### Now plot PMP with 50, 500, and 5000 visitors.

# %%
p = 0.15

for n in [50, 500, 5000]:
    k = range(0, n + 1)
    pmf = binom.pmf(k, n, p)

    plt.figure()
    plt.bar(k, pmf)
    plt.xlabel("Number of Clicks")
    plt.ylabel("Probability")
    plt.title(f"Binomial PMF (n = {n}, p = 0.15)")
    plt.show()

# %% [markdown]
# #### What did you notice from the distribution plots? Comment your findings.

# %%
# the probability lowers and the discribution thins

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Reaserch the Poisson distribution. Write about your own understanding of the Poisson distribution.

# %%
# In my understanding, the Poisson distribution is a powerful tool for modeling random counts of events that happen independently over time or space when we only know the average rate. It is especially useful for rare events and simplifies calculations compared to the binomial distribution when the number of trials is very large.

# %% [markdown]
# #### A website has an average of 300 visits per day. What is the probability of getting 320 visitors in a day?
#
# *Hint: use `scipy.stats.poisson`*

# %%
from scipy.stats import poisson

lam = 300   # average visits
k = 320     # desired number of visitors

probability = poisson.pmf(k, lam)

print(probability)
# Out:
# 0.011612348610402475

# %% [markdown]
# #### What is the probability of getting 60 visits?

# %%
lam = 300
k = 60

probability = poisson.pmf(k, lam)

print(probability)
# Out:
# 2.622743762294515e-64

# %% [markdown]
# #### Plot the distribution of the probability for getting 0-1000 visits.
#
# *Hints:*
#
# - Create a list to store the Poisson distribution probabilities for n=0 to 1000. Then plot the probabilities.
#
# - Your plot should look like below:
#
# ![poisson distribution](ch-3.png)

# %%
lam = 300

# Create range from 0 to 1000
k = range(0, 1001)

# Compute Poisson probabilities
probabilities = poisson.pmf(k, lam)

# Plot
plt.figure()
plt.plot(k, probabilities)
plt.xlabel("Number of Visits")
plt.ylabel("Probability")
plt.title("Poisson Distribution")
plt.show()
